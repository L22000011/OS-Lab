# %%
import random

def create_file(file_name, file_size):
    # 模拟创建文件的过程
    # 在磁盘中找到足够大小的空闲块，将文件存储到这些块中
    print("创建文件", file_name, "大小：", file_size)

def delete_file(file_name):
    # 模拟删除文件的过程
    # 释放文件占用的磁盘块
    print("删除文件", file_name)

def show_disk_status():
    # 显示文件的盘块存储状态和所有空闲区块的状态
    print("盘块存储状态：")
    # 显示文件A.txt、B.txt、C.txt、D.txt、E.txt的盘块存储状态
    print("文件A.txt的盘块存储状态：")
    # 显示文件B.txt的盘块存储状态
    print("文件B.txt的盘块存储状态：")
    # 显示文件C.txt的盘块存储状态
    print("文件C.txt的盘块存储状态：")
    # 显示文件D.txt的盘块存储状态
    print("文件D.txt的盘块存储状态：")
    # 显示文件E.txt的盘块存储状态
    print("文件E.txt的盘块存储状态：")

    print("空闲区块状态：")
    # 显示所有空闲区块的状态

# 主程序
disk_blocks = list(range(1, 501))  # 初始化磁盘块序列
free_blocks = disk_blocks[:]  # 初始化所有块为空闲块

# 选择一种空闲块管理算法，并使用该算法管理空闲块

# 创建50个文件并存储到磁盘中
for i in range(1, 51):
    file_name = str(i) + ".txt"
    file_size = random.randint(2, 10) * 1024  # 生成文件大小（2k到10k之间）
    create_file(file_name, file_size)

# 删除奇数编号的文件
for i in range(1, 50, 2):
    file_name = str(i) + ".txt"
    delete_file(file_name)

# 新创建5个文件并存储到磁盘中
files_to_create = [("A.txt", 7 * 1024), ("B.txt", 5 * 1024), ("C.txt", 2 * 1024), ("D.txt", 9 * 1024), ("E.txt", 3.5 * 1024)]
for file_name, file_size in files_to_create:
    create_file(file_name, file_size)

# 显示文件的盘块存储状态和所有空闲区块的状态
show_disk_status()
# Out:
# 创建文件 1.txt 大小： 8192
# 创建文件 2.txt 大小： 7168
# 创建文件 3.txt 大小： 2048
# 创建文件 4.txt 大小： 5120
# 创建文件 5.txt 大小： 5120
# 创建文件 6.txt 大小： 2048
# 创建文件 7.txt 大小： 7168
# 创建文件 8.txt 大小： 8192
# 创建文件 9.txt 大小： 9216
# 创建文件 10.txt 大小： 3072
# 创建文件 11.txt 大小： 10240
# 创建文件 12.txt 大小： 2048
# 创建文件 13.txt 大小： 5120
# 创建文件 14.txt 大小： 6144
# 创建文件 15.txt 大小： 8192
# 创建文件 16.txt 大小： 7168
# 创建文件 17.txt 大小： 4096
# 创建文件 18.txt 大小： 10240
# 创建文件 19.txt 大小： 9216
# 创建文件 20.txt 大小： 4096
# 创建文件 21.txt 大小： 5120
# 创建文件 22.txt 大小： 6144
# 创建文件 23.txt 大小： 5120
# 创建文件 24.txt 大小： 7168
# 创建文件 25.txt 大小： 10240
# 创建文件 26.txt 大小： 8192
# 创建文件 27.txt 大小： 6144
# 创建文件 28.txt 大小： 3072
# 创建文件 29.txt 大小： 5120
# 创建文件 30.txt 大小： 7168
# 创建文件 31.txt 大小： 9216
# 创建文件 32.txt 大小： 5120
# 创建文件 33.txt 大小： 7168
# 创建文件 34.txt 大小： 9216
# 创建文件 35.txt 大小： 4096
# 创建文件 36.txt 大小： 10240
# 创建文件 37.txt 大小： 5120
# 创建文件 38.txt 大小： 6144
# 创建文件 39.txt 大小： 8192
# 创建文件 40.txt 大小： 10240
# 创建文件 41.txt 大小： 8192
# 创建文件 42.txt 大小： 4096
# 创建文件 43.txt 大小： 5120
# ...
